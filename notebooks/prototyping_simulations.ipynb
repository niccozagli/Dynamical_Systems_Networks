# %%
from dyn_net.dynamical_systems import get_drift
from dyn_net.noise import get_noise
from dyn_net.integrator.euler_maruyama import euler_maruyama_isotropic
from dyn_net.integrator.params import EulerMaruyamaParams
from dyn_net.dynamical_systems.stats_registry import get_stats
from dyn_net.utils.stats import open_stats_writer, close_stats_writer
import numpy as np

# %%
# Parameters system
system = "double_well_single"

params_double_well_single = {
    'alpha_rot' : 5
}
params_noise = {
    'sigma' : 0.3
}

# Parameters integrator
p_int = EulerMaruyamaParams(
    tmin=0.0,
    tmax=100000.0,
    dt=0.001,
    stats_every=100,
    write_stats_at_start=True,
)

# %%
F, pF = get_drift(system, params_double_well_single)
G, pG = get_noise("additive_gaussian", params_noise)
stats_fn, stats_fields = get_stats(system)

# %%
stats_writer = open_stats_writer(
    "stats.h5",
    fieldnames=stats_fields,
)

# %%
x0 = np.array([-2.0,3])   # or high-dimensional array

try:
    x_final = euler_maruyama_isotropic(
        F, G,
        x0,
        params_int=p_int,
        params_F=pF,
        params_G=pG,
        stats_fn=stats_fn,
        stats_writer=stats_writer,
    )
finally:
    close_stats_writer(stats_writer)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 x0 = np.array([-2.0,3])   # or high-dimensional array
#       3 try:
# ----> 4     x_final = euler_maruyama_isotropic(
#       5         F, G,
#       6         x0,
#       7         params_int=p_int,
#       8         params_F=pF,
#       9         params_G=pG,
#      10         stats_fn=stats_fn,
#      11         stats_writer=stats_writer,
#      12     )
#      13 finally:
#      14     close_stats_writer(stats_writer)
#
# File ~/Desktop/Dynamics_Networks/src/dyn_net/integrator/euler_maruyama.py:35, in euler_maruyama_isotropic(F, G, x0, params_int, params_F, params_G, rng, stats_fn, stats_writer)
#      31     write_stats(stats_writer, stats_fn(x, t, 0, params_F))
#      34 for step in range(1, n + 1):
# ---> 35     drift = np.asarray(F(x, t, params_F), dtype=float).reshape(d)
#      36     sigma = float(G(x, t, params_G))
#      38     x = x + dt * drift + sqrt_dt * sigma * rng.normal(size=d)
#
# KeyboardInterrupt:
