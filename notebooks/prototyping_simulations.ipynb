# %%
from dyn_net.dynamical_systems import get_drift
from dyn_net.noise import get_noise
from dyn_net.integrator.euler_maruyama import euler_maruyama_isotropic
from dyn_net.integrator.params import EulerMaruyamaParams
from dyn_net.dynamical_systems.stats_registry import get_stats
from dyn_net.utils.stats import open_stats_writer, close_stats_writer
from dyn_net.utils.state import open_state_writer, close_state_writer
import numpy as np

# %%
# Parameters system
system = "double_well_single"

params_double_well_single = {
    'alpha_rot' : 5
}
params_noise = {
    'sigma' : 0.3
}

# Parameters integrator
p_int = EulerMaruyamaParams(
    tmin=0.0,
    tmax=100000.0,
    dt=0.001,
    stats_every=100,
    state_every=500,
    write_stats_at_start=True,
    write_state_at_start=True
)

# Initial condition
x0 = np.array([-2.0,3])   # or high-dimensional array

# %%
F, pF = get_drift(system, params_double_well_single)
G, pG = get_noise("additive_gaussian", params_noise)
stats_fn, stats_fields = get_stats(system)

# %%
stats_writer = open_stats_writer(
    "stats.h5",
    fieldnames=stats_fields,
)

state_writer = open_state_writer(
    "state.h5",
    dim=len(x0),
)

# %%
try:
    x_final = euler_maruyama_isotropic(
        F, G,
        x0,
        params_int=p_int,
        params_F=pF,
        params_G=pG,
        stats_fn=stats_fn,
        stats_writer=stats_writer,
        state_writer=state_writer,
    )
finally:
    close_stats_writer(stats_writer)
    close_state_writer(state_writer)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 try:
# ----> 2     x_final = euler_maruyama_isotropic(
#       3         F, G,
#       4         x0,
#       5         params_int=p_int,
#       6         params_F=pF,
#       7         params_G=pG,
#       8         stats_fn=stats_fn,
#       9         stats_writer=stats_writer,
#      10         state_writer=state_writer,
#      11     )
#      12 finally:
#      13     close_stats_writer(stats_writer)
#
# File ~/Desktop/Dynamics_Networks/src/dyn_net/integrator/euler_maruyama.py:47, in euler_maruyama_isotropic(F, G, x0, params_int, params_F, params_G, rng, stats_fn, stats_writer, state_writer)
#      44 t = tmin + step * dt
#      46 if step % stats_every == 0:
# ---> 47     write_stats(stats_writer, stats_fn(x, t, step, params_F))
#      48 if state_writer is not None and step % state_every == 0:
#      49     write_state(state_writer, x, t, step)
#
# File ~/Desktop/Dynamics_Networks/src/dyn_net/utils/stats.py:60, in write_stats(writer, row)
#      58 dset[idx, :] = arr
#      59 writer[4] = idx + 1  # update index in-place
# ---> 60 fh.flush()
#
# File ~/Desktop/Dynamics_Networks/.venv/lib/python3.13/site-packages/h5py/_hl/files.py:641, in File.flush(self)
#     638 """ Tell the HDF5 library to flush its buffers.
#     639 """
#     640 with phil:
# --> 641     h5f.flush(self.id)
#
# KeyboardInterrupt:
